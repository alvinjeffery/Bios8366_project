# %% [markdown]
# ## To Do
#
# - Finish transfer counts variable (after recoding suspect transfers)
# - Get rid of double admits w/ differing service codes
# - Rename all column variables to lower case
# - Expand out the final patient data frame with visit ids & rows per each day in the hospital
#
# Shape of final table:
#
# | RUID | Visit_ID | Admit_Date | Discharge_Date | Hospital_Day | N_Transfers | Stay_Length | Readmit_Time | 30d_Readmit |
# |------|----------|------------|----------------|--------------|-------------|-------------|--------------|-------------|
# | user id | hospital stay # | date admitted | date discharged | date in hospital | number of transfers | duration of stay | time from last discharge to this admission | was the patient a 30d readmit? |
#
#
# ## Nice-to-do
#
# - Construct missing discharge/admit dates from CPT codes (as above) -- do not do this for events where both are missing as these may be ER visits w/o admit, but do check if they fall in the range of an existing stay
# - Characterize the amount of missingness of entire hospital visits from CPT codes

# %% [markdown]
# ## Loading data

# %%
# %ls ../data
# Out:
# FONNESBECK_ADT_20151202.csv        FONNESBECK_ICD9_20151202.csv*
# FONNESBECK_BMI_20151202.csv*       FONNESBECK_LAB_20151202.csv*
# FONNESBECK_BP_20151202.csv*        FONNESBECK_MED_20151202.csv*
# FONNESBECK_CPT_20151202.csv*       FONNESBECK_phenotype_20151202.csv*
# FONNESBECK_EGFR_20151202.csv*      Fonnesbeck_DD_2014102014.xlsx

# %%
import pandas as pd
import datetime
import numpy as np

# %%
adt = pd.read_table('../data/FONNESBECK_ADT_20151202.csv', encoding='latin1', sep = ',', infer_datetime_format=True, parse_dates=['Admission_date','Event_Date','DISCHARGE_DATE'])
pheno = pd.read_table('../data/FONNESBECK_phenotype_20151202.csv', encoding='latin1', sep = ',', infer_datetime_format=True, parse_dates=['DOB','DOD'])
cpt = pd.read_table('../data/FONNESBECK_CPT_20151202.csv', encoding='latin1', sep = ',', infer_datetime_format=True, parse_dates=['Event_date'])

# %%
svc = pd.read_excel('../data/FONNESBECK_DD_2014102014.xlsx',sheet_name='Service code', sep = ',')
svc.rename(columns = {"Service Code":"SVC", "Service Code Desc":"Desc"}, inplace = True)

# %%
adt.Event = pd.Categorical(adt.Event,categories = ['Admit','Transfer','Discharge'])
adt = adt.sort_values(by = ['RUID','Admission_date','Event','Event_Date']).reset_index(drop = True)
adt.head()
# Out:
#        RUID      Event Admission_date Event_Date SRV_CODE CHIEF_COMPLAINT  \
# 0  50135262      Admit     2007-02-08 2007-02-08      ORT      R FEMUR FX
# 1  50135262   Transfer     2007-02-08 2007-02-08      ORT      R FEMUR FX
# 2  50135262   Transfer     2007-02-08 2007-02-09      ORT      R FEMUR FX
# 3  50135262  Discharge     2007-02-08 2007-02-12      ORT      R FEMUR FX
# 4  50135262      Admit     2007-08-03 2007-08-03      CAR              CP
#
#   DISCHARGE_DATE
# 0     2007-02-12
# 1     2007-02-12
# 2     2007-02-12
# 3     2007-02-12
# 4     2007-08-06

# %%
adt.describe(include='all')
# Out:
#                 RUID     Event       Admission_date           Event_Date  \
# count   1.215300e+05    121530               119969               121530
# unique           NaN         3                 4192                 4279
# top              NaN  Transfer  2013-03-14 00:00:00  2013-12-28 00:00:00
# freq             NaN     61636                  111                   69
# first            NaN       NaN  2004-01-28 00:00:00  2004-01-28 00:00:00
# last             NaN       NaN  2015-11-26 00:00:00  2015-11-26 00:00:00
# mean    5.366861e+07       NaN                  NaN                  NaN
# std     4.628206e+05       NaN                  NaN                  NaN
# min     5.013526e+07       NaN                  NaN                  NaN
# 25%     5.372980e+07       NaN                  NaN                  NaN
# 50%     5.373203e+07       NaN                  NaN                  NaN
# 75%     5.373430e+07       NaN                  NaN                  NaN
# max     5.373642e+07       NaN                  NaN                  NaN
#
#        SRV_CODE CHIEF_COMPLAINT       DISCHARGE_DATE
# count    121530          120603               119472
# unique       73           13118                 4195
# top         GMD          296.90  2010-12-23 00:00:00
# freq      13062            2394                  111
# first       NaN             NaN  2004-02-11 00:00:00
# last        NaN             NaN  2015-11-23 00:00:00
# mean        NaN             NaN                  NaN
# std         NaN             NaN                  NaN
# min         NaN             NaN                  NaN
# 25%         NaN             NaN                  NaN
# 50%         NaN             NaN                  NaN
# 75%         NaN             NaN                  NaN
# max         NaN             NaN                  NaN

# %% [markdown]
# ## Looking at missingness

# %%
adt.isnull().sum()/adt.shape[0]
# Out:
# RUID               0.000000
# Event              0.000000
# Admission_date     0.012845
# Event_Date         0.000000
# SRV_CODE           0.000000
# CHIEF_COMPLAINT    0.007628
# DISCHARGE_DATE     0.016934
# dtype: float64

# %%
adt[adt.Admission_date.isnull() & adt.DISCHARGE_DATE.isnull()].SRV_CODE.value_counts() # may correspond to ER visits without admission which we don't need to predict
# Out:
# CAR    295
# GMD    269
# PED    110
# NEP     69
# GER     55
# PUL     51
# GNS     46
# OBS     45
# ORT     43
# INF     40
# NES     38
# ONC     37
# PGS     37
# HEM     34
# PON     34
# URO     32
# NEU     31
# GAS     23
# EMR     22
# TRA     20
# OTO     20
# HEP     17
# PLS     16
# EGS     15
# LTS     14
# PCC     14
# PGA     14
# PNP     11
# BRN     10
# PCA     10
# PPU      9
# PNE      9
# CSX      8
# RTS      8
# VAS      7
# PSY      6
# PEN      5
# GIL      4
# OES      4
# GYN      4
# DIA      3
# CLP      3
# GEN      2
# THS      2
# NEO      2
# PTA      2
# ADO      2
# RAD      2
# CTS      2
# RHM      1
# Name: SRV_CODE, dtype: int64

# %%
adt[~(adt.Admission_date.isnull() & adt.DISCHARGE_DATE.isnull())].RUID.value_counts() # may correspond to ER visits without admission which we don't need to predict
# Out:
# 53736286    372
# 53730141    366
# 53734944    308
# 53728578    288
# 53728001    282
# 53733747    258
# 53732256    244
# 53729476    230
# 53735136    229
# 53734271    213
# 53733351    211
# 53728778    204
# 53734307    202
# 53730096    198
# 50135437    186
# 53729313    185
# 53729615    183
# 53730488    181
# 53732315    174
# 53728340    173
# 53729068    171
# 53732869    170
# 53730727    169
# 53728652    168
# 53734565    166
# 53732346    161
# 53730100    160
# 53728903    158
# 53734444    156
# 53728993    155
#            ...
# 53729940      2
# 53729333      2
# 53731726      2
# 53734715      2
# 53732862      2
# 53731525      2
# 53732820      2
# 53733178      2
# 53736116      2
# 53729845      2
# 53736347      2
# 53728159      2
# 53728073      2
# 53735560      2
# 53732199      2
# 53732195      2
# 53735295      2
# 53733577      2
# 53733318      2
# 53719683      2
# 53728013      2
# 53734595      2
# 53733451      2
# 53730759      2
# 53733285      2
# 53735332      2
# 53728118      1
# 53725969      1
# 53734229      1
# 53730935      1
# Name: RUID, Length: 7915, dtype: int64

# %%
adt[adt.Admission_date.isnull()].Event.value_counts()
# Out:
# Transfer     1559
# Discharge       2
# Admit           0
# Name: Event, dtype: int64

# %%
adt[adt.DISCHARGE_DATE.isnull()].Event.value_counts()
# Out:
# Transfer     1860
# Admit         198
# Discharge       0
# Name: Event, dtype: int64

# %%
adt[(adt.Admission_date.isnull()) & (adt.Event == 'Discharge')]
# Out:
#            RUID      Event Admission_date Event_Date SRV_CODE CHIEF_COMPLAINT  \
# 76409  53733158  Discharge            NaT 2007-08-06      TRA            STAT
# 76578  53733172  Discharge            NaT 2013-02-17      PED          SEPSIS
#
#       DISCHARGE_DATE
# 76409     2007-08-06
# 76578     2013-02-17

# %%
adt[76400:76420]
# Out:
#            RUID      Event Admission_date Event_Date SRV_CODE  \
# 76400  53733157      Admit     2012-02-14 2012-02-14      PUL
# 76401  53733157   Transfer     2012-02-14 2012-02-14      PUL
# 76402  53733157  Discharge     2012-02-14 2012-02-15      PUL
# 76403  53733157      Admit     2012-04-14 2012-04-14      ONC
# 76404  53733157   Transfer     2012-04-14 2012-04-14      ONC
# 76405  53733157  Discharge     2012-04-14 2012-04-15      ONC
# 76406  53733157   Transfer            NaT 2011-11-21      ONC
# 76407  53733157   Transfer            NaT 2011-11-21      HEM
# 76408  53733158   Transfer            NaT 2007-08-05      TRA
# 76409  53733158  Discharge            NaT 2007-08-06      TRA
# 76410  53733159      Admit     2007-03-08 2007-03-08      PON
# 76411  53733159   Transfer     2007-03-08 2007-03-08      PON
# 76412  53733159  Discharge     2007-03-08 2007-03-10      PON
# 76413  53733159      Admit     2007-03-15 2007-03-15      PON
# 76414  53733159   Transfer     2007-03-15 2007-03-15      PON
# 76415  53733159  Discharge     2007-03-15 2007-03-17      PON
# 76416  53733159      Admit     2007-08-11 2007-08-11      OTO
# 76417  53733159  Discharge     2007-08-11 2007-08-16      OTO
# 76418  53733159      Admit     2007-09-14 2007-09-14      PON
# 76419  53733159  Discharge     2007-09-14 2007-09-15      PON
#
#                                  CHIEF_COMPLAINT DISCHARGE_DATE
# 76400                                 HEMOPTYSIS     2012-02-15
# 76401                                 HEMOPTYSIS     2012-02-15
# 76402                                 HEMOPTYSIS     2012-02-15
# 76403  FAILURE TO THRIVE; DEHYDRATION; KIDNEY CA     2012-04-15
# 76404  FAILURE TO THRIVE; DEHYDRATION; KIDNEY CA     2012-04-15
# 76405  FAILURE TO THRIVE; DEHYDRATION; KIDNEY CA     2012-04-15
# 76406                                 HEMOPTYSIS            NaT
# 76407                                 HEMOPTYSIS            NaT
# 76408                                       STAT     2007-08-06
# 76409                                       STAT     2007-08-06
# 76410                                  PNEUMONIA     2007-03-10
# 76411                                  PNEUMONIA     2007-03-10
# 76412                                  PNEUMONIA     2007-03-10
# 76413                         SICKLE CELL CRISIS     2007-03-17
# 76414                         SICKLE CELL CRISIS     2007-03-17
# 76415                         SICKLE CELL CRISIS     2007-03-17
# 76416        HYPERTROPHY TONSILS/ADENOIDS 474.10     2007-08-16
# 76417        HYPERTROPHY TONSILS/ADENOIDS 474.10     2007-08-16
# 76418                                      FEVER     2007-09-15
# 76419                                      FEVER     2007-09-15

# %% [markdown]
# ## Adding age data & removing pediatric patients

# %%
adt_age = pd.merge(adt,pheno)
# admits = adt_age.Admission_date.dt
events = adt_age.Event_Date.dt
birthdays = adt_age.DOB.dt

adt_age['age'] = events.year - birthdays.year + ((events.month < birthdays.month) & (events.day < birthdays.day))
# above from https://stackoverflow.com/questions/2217488/age-from-birthdate-in-python/9754466#9754466

# %%
# getting rid of peds & psychiatric patients...
# we're removing these because they aren't part of the CMS criteria so 30-day readmits for them don't lose the hospital money
ped_svc = '|'.join(svc.SVC[svc.Desc.str.contains("CHILD|PED")])
psych_svc = '|'.join(svc.SVC[svc.Desc.str.contains("PSYCH")])

# ped_filter = ((adt_age.age < 18) | (adt_age.SRV_CODE.str.contains(ped_svc)) & ~((adt_age.age > 35) & (adt_age.SRV_CODE.str.contains(ped_svc))))
# the ~ condition here contains a handful of rows that I think are coding errors -- very old patients admitted to pediatric services
# the cutoff is 35 because some pediatric cancer/cardiac/etc patients will continue with pediatric services for their original condition into adulthood

ped_filter = (adt_age.age < 18)
psych_filter = (adt_age.SRV_CODE.str.contains(psych_svc))

# doing this the simplest way possible
# the psych filter will remove patients with a primary psych admit, which removes them from our consideration, but NOT patients who have psych consults
# may want to explicitly do that

# %%
adt_cms = adt[~(ped_filter | psych_filter)]

# %%
adt_cms.RUID.value_counts()
# Out:
# 53736286    374
# 53730141    363
# 53734944    310
# 53728578    289
# 53728001    288
# 53733747    251
# 53732256    241
# 53735136    229
# 53734271    213
# 53733351    211
# 53728778    203
# 53734307    201
# 53730096    197
# 53729313    185
# 53732315    179
# 53732869    173
# 53732346    172
# 53729068    172
# 53734565    171
# 53730727    171
# 53728652    170
# 50135437    158
# 53734444    156
# 53729615    156
# 53729476    154
# 53728484    152
# 53729822    151
# 53728993    148
# 53730650    138
# 53735152    138
#            ...
# 53732205      1
# 53731426      1
# 53728118      1
# 53730326      1
# 53730090      1
# 53730359      1
# 53730455      1
# 53731825      1
# 53730935      1
# 53734229      1
# 53727900      1
# 53729049      1
# 53734455      1
# 53732402      1
# 53734873      1
# 53731186      1
# 53729118      1
# 53733934      1
# 53734585      1
# 53728287      1
# 53734947      1
# 53731709      1
# 53729274      1
# 53736078      1
# 53728853      1
# 53732870      1
# 53732755      1
# 53728405      1
# 53730338      1
# 53732390      1
# Name: RUID, Length: 5757, dtype: int64

# %% [markdown]
# ## Filtering to admits & eliminating missing discharges

# %%
adt_cms_admits = adt_cms[(adt_cms.Event == 'Admit') & ~(adt_cms.DISCHARGE_DATE.isnull())].copy()
# removing missing discharge dates because I can't fix them right now
# adt_cms[(adt_cms.Event == 'Admit') & (adt_cms.DISCHARGE_DATE.isnull())]

# adt_cms_admits = adt_cms_admits[adt_cms_admits.Admission_date == adt_cms_admits.Event_Date].reset_index(drop = True)
# this removes admits that aren't the same day as the admit date
# i'm not sure what these actually are--they might be miscoded transfers or admissions to another department

# %% [markdown]
# ## Constructing variables

# %%
adt_cms_admits['Stay_length'] = adt_cms_admits.DISCHARGE_DATE - adt_cms_admits.Admission_date
adt_cms_admits['Readmit_time'] = adt_cms_admits.Admission_date - adt_cms_admits.DISCHARGE_DATE.shift()

didx = ~(adt_cms_admits.RUID.shift() == adt_cms_admits.RUID)

adt_cms_admits['Readmit_time'] = adt_cms_admits['Readmit_time'].mask(didx)

adt_cms_admits['30d_readmit'] = np.where(adt_cms_admits.Readmit_time <= datetime.timedelta(days=30),1,0)

# %%
adt_cms_admits[(adt_cms_admits.Readmit_time < datetime.timedelta(days=0)) | (adt_cms_admits.Readmit_time.shift(-1) < datetime.timedelta(days=0))] # this appears to happen when we've got two admit events for the same date with the same discharge
# in some cases they have different event dates, in other cases they're identical but have different srv_codes
# the first type might be miscoded transfers; the second type probably needs to be squished together
# ANSWERED: recode suspect transfers as Transfer but add column for "Imputed Transfer" to flag them so we can either use or not use them for Transfer counts
# Out:
#             RUID  Event Admission_date Event_Date SRV_CODE  \
# 460     50135624  Admit     2015-06-24 2015-06-24      CAR
# 461     50135624  Admit     2015-06-24 2015-06-25      CAR
# 528     50135821  Admit     2013-10-24 2013-10-24      GMD
# 529     50135821  Admit     2013-10-24 2013-10-27      GMD
# 1573    50139667  Admit     2014-10-02 2014-10-02      CAR
# 1574    50139667  Admit     2014-10-02 2014-10-03      CAR
# 1768    50141958  Admit     2014-03-11 2014-03-11      PUL
# 1769    50141958  Admit     2014-03-11 2014-03-12      PUL
# 1804    50142794  Admit     2014-08-11 2014-08-11      CAR
# 1805    50142794  Admit     2014-08-11 2014-08-12      CAR
# 2489    53719335  Admit     2014-04-24 2014-04-24      GMD
# 2490    53719335  Admit     2014-04-24 2014-04-25      GMD
# 2518    53719335  Admit     2015-03-01 2015-03-01      GMD
# 2519    53719335  Admit     2015-03-01 2015-03-02      GMD
# 2529    53719335  Admit     2015-04-02 2015-04-02      GMD
# 2530    53719335  Admit     2015-04-02 2015-04-04      GMD
# 2550    53719857  Admit     2014-08-25 2014-08-25      GMD
# 2551    53719857  Admit     2014-08-25 2014-08-26      GMD
# 2809    53725468  Admit     2014-11-14 2014-11-14      CSX
# 2810    53725468  Admit     2014-11-14 2014-11-15      PUL
# 3038    53727830  Admit     2013-12-25 2013-12-25      ORT
# 3039    53727830  Admit     2013-12-25 2013-12-26      ORT
# 3201    53727848  Admit     2014-02-01 2014-02-01      GMD
# 3202    53727848  Admit     2014-02-01 2014-02-04      GMD
# 3303    53727859  Admit     2014-04-21 2014-04-21      EMR
# 3304    53727859  Admit     2014-04-21 2014-04-22      GMD
# 3994    53727911  Admit     2014-05-21 2014-05-21      PUL
# 3995    53727911  Admit     2014-05-21 2014-05-21      CAR
# 3996    53727911  Admit     2014-05-21 2014-05-23      PUL
# 4017    53727915  Admit     2014-02-09 2014-02-09      TRA
# ...          ...    ...            ...        ...      ...
# 118493  53736237  Admit     2013-07-29 2013-07-29      GMD
# 118494  53736237  Admit     2013-07-29 2013-07-30      GMD
# 118622  53736242  Admit     2013-12-17 2013-12-17      CAR
# 118623  53736242  Admit     2013-12-17 2013-12-18      CAR
# 118837  53736262  Admit     2015-05-03 2015-05-03      CAR
# 118838  53736262  Admit     2015-05-03 2015-05-04      CAR
# 119399  53736286  Admit     2014-03-14 2014-03-14      HEM
# 119400  53736286  Admit     2014-03-14 2014-03-15      HEM
# 119440  53736286  Admit     2014-10-26 2014-10-26      HEM
# 119441  53736286  Admit     2014-10-26 2014-10-29      HEM
# 119542  53736290  Admit     2014-10-12 2014-10-12      CAR
# 119543  53736290  Admit     2014-10-12 2014-10-13      CAR
# 119646  53736299  Admit     2014-06-22 2014-06-22      NEP
# 119647  53736299  Admit     2014-06-22 2014-06-25      NEP
# 119827  53736308  Admit     2014-12-12 2014-12-12      CAR
# 119828  53736308  Admit     2014-12-12 2014-12-14      CAR
# 120284  53736327  Admit     2015-05-25 2015-05-25      NEP
# 120285  53736327  Admit     2015-05-25 2015-05-26      NEP
# 120624  53736349  Admit     2015-01-19 2015-01-19      CAR
# 120625  53736349  Admit     2015-01-19 2015-01-20      CAR
# 120636  53736350  Admit     2015-09-13 2015-09-13      GMD
# 120637  53736350  Admit     2015-09-13 2015-09-14      GMD
# 120874  53736369  Admit     2014-06-27 2014-06-27      TRA
# 120875  53736369  Admit     2014-06-27 2014-06-28      BRN
# 120978  53736379  Admit     2014-02-03 2014-02-03      PUL
# 120979  53736379  Admit     2014-02-03 2014-02-04      GMD
# 121380  53736415  Admit     2014-06-30 2014-06-30      CAR
# 121381  53736415  Admit     2014-06-30 2014-07-01      CAR
# 121422  53736417  Admit     2014-01-26 2014-01-26      HEP
# 121423  53736417  Admit     2014-01-26 2014-01-26      GMD
#
#                                        CHIEF_COMPLAINT DISCHARGE_DATE  \
# 460                                                SOB     2015-06-28
# 461                                                SOB     2015-06-28
# 528                                            LEG LAC     2013-10-29
# 529                                            LEG LAC     2013-10-29
# 1573                                  CHF EXACERBATION     2014-10-22
# 1574                                  CHF EXACERBATION     2014-10-22
# 1768                                            TRAUMA     2014-03-13
# 1769                                            TRAUMA     2014-03-13
# 1804                                               CHF     2014-08-18
# 1805                                               CHF     2014-08-18
# 2489                                          GI BLEED     2014-04-25
# 2490                                          GI BLEED     2014-04-25
# 2518                                               PNA     2015-03-04
# 2519                                               PNA     2015-03-04
# 2529                                               N/V     2015-04-13
# 2530                                               N/V     2015-04-13
# 2550                                            HYPERK     2014-08-27
# 2551                                            HYPERK     2014-08-27
# 2809                  S/P LIVER TXPLANT; RENAL FAILURE     2014-11-27
# 2810                  S/P LIVER TXPLANT; RENAL FAILURE     2014-11-27
# 3038                                          CSF LEAK     2013-12-30
# 3039                                          CSF LEAK     2013-12-30
# 3201                                              RASH     2014-02-04
# 3202                                              RASH     2014-02-04
# 3303                                               AMS     2014-04-27
# 3304                                               AMS     2014-04-27
# 3994                                               ACS     2014-05-29
# 3995                                               ACS     2014-05-29
# 3996                                               ACS     2014-05-29
# 4017                                               GSW     2014-02-10
# ...                                                ...            ...
# 118493                                            PAIN     2013-07-31
# 118494                                            PAIN     2013-07-31
# 118622                             428.9 HEART FAILURE     2013-12-26
# 118623                             428.9 HEART FAILURE     2013-12-26
# 118837                                              CP     2015-05-04
# 118838                                              CP     2015-05-04
# 119399                                             SCC     2014-03-19
# 119400                                             SCC     2014-03-19
# 119440                                            PAIN     2014-11-07
# 119441                                            PAIN     2014-11-07
# 119542                                      CHEST PAIN     2014-10-24
# 119543                                      CHEST PAIN     2014-10-24
# 119646                                             AKI     2014-07-15
# 119647                                             AKI     2014-07-15
# 119827                                          NSTEMI     2014-12-16
# 119828                                          NSTEMI     2014-12-16
# 120284                                 VOMITING/XPLANT     2015-06-01
# 120285                                 VOMITING/XPLANT     2015-06-01
# 120624  NSTEMI; ABDOMIANL PAIN; MALIGNANT HYPERTENSION     2015-01-21
# 120625  NSTEMI; ABDOMIANL PAIN; MALIGNANT HYPERTENSION     2015-01-21
# 120636                                         SYNCOPE     2015-09-27
# 120637                                         SYNCOPE     2015-09-27
# 120874           GRAFT-VERSUS-HOSTDISEASE-279.50/948.2     2014-07-12
# 120875           GRAFT-VERSUS-HOSTDISEASE-279.50/948.2     2014-07-12
# 120978                                        SEIZURES     2014-02-09
# 120979                                        SEIZURES     2014-02-09
# 121380                                    427.31 A FIB     2014-07-01
# 121381                                    427.31 A FIB     2014-07-01
# 121422                                   LIVER FAILURE     2014-02-03
# 121423                                   LIVER FAILURE     2014-02-03
#
#        Stay_length Readmit_time  30d_readmit
# 460         4 days      94 days            0
# 461         4 days      -4 days            1
# 528         5 days       6 days            1
# 529         5 days      -5 days            1
# 1573       20 days     900 days            0
# 1574       20 days     -20 days            1
# 1768        2 days          NaT            0
# 1769        2 days      -2 days            1
# 1804        7 days      12 days            1
# 1805        7 days      -7 days            1
# 2489        1 days      18 days            1
# 2490        1 days      -1 days            1
# 2518        3 days      22 days            1
# 2519        3 days      -3 days            1
# 2529       11 days       9 days            1
# 2530       11 days     -11 days            1
# 2550        2 days          NaT            0
# 2551        2 days      -2 days            1
# 2809       13 days      11 days            1
# 2810       13 days     -13 days            1
# 3038        5 days          NaT            0
# 3039        5 days      -5 days            1
# 3201        3 days      58 days            0
# 3202        3 days      -3 days            1
# 3303        6 days          NaT            0
# 3304        6 days      -6 days            1
# 3994        8 days     378 days            0
# 3995        8 days      -8 days            1
# 3996        8 days      -8 days            1
# 4017        1 days          NaT            0
# ...            ...          ...          ...
# 118493      2 days     279 days            0
# 118494      2 days      -2 days            1
# 118622      9 days      10 days            1
# 118623      9 days      -9 days            1
# 118837      1 days     125 days            0
# 118838      1 days      -1 days            1
# 119399      5 days      30 days            1
# 119400      5 days      -5 days            1
# 119440     12 days      14 days            1
# 119441     12 days     -12 days            1
# 119542     12 days      11 days            1
# 119543     12 days     -12 days            1
# 119646     23 days          NaT            0
# 119647     23 days     -23 days            1
# 119827      4 days     192 days            0
# 119828      4 days      -4 days            1
# 120284      7 days      47 days            0
# 120285      7 days      -7 days            1
# 120624      2 days     286 days            0
# 120625      2 days      -2 days            1
# 120636     14 days     582 days            0
# 120637     14 days     -14 days            1
# 120874     15 days     118 days            0
# 120875     15 days     -15 days            1
# 120978      6 days     879 days            0
# 120979      6 days      -6 days            1
# 121380      1 days          NaT            0
# 121381      1 days      -1 days            1
# 121422      8 days          NaT            0
# 121423      8 days      -8 days            1
#
# [876 rows x 10 columns]

# %%
event_counts = adt_cms[~(adt_cms.DISCHARGE_DATE.isnull())].groupby(by=['RUID','Admission_date']).Event.value_counts(sort=False).unstack(fill_value = 0)
event_counts['Transfer'] # now pull the number of transfers and we're good
# Out:
# RUID      Admission_date
# 50135262  2007-02-08        2
#           2007-08-03        3
#           2007-08-28        1
#           2008-02-24        2
#           2008-04-12        1
#           2010-10-28        1
#           2011-02-11        4
#           2012-05-23        1
#           2012-09-15        1
#           2014-11-15        2
# 50135361  2007-12-16        3
#           2008-08-02        1
#           2008-10-20        1
#           2008-10-30        1
#           2008-11-04        2
#           2008-12-02        3
#           2009-03-03        3
#           2009-03-29        3
#           2011-10-10        1
#           2011-10-20        1
#           2012-01-08        0
#           2012-06-09        1
#           2012-06-17        1
#           2012-07-27        6
# 50135369  2004-11-24        0
#           2005-04-21        1
#           2006-01-27        1
#           2006-02-20        1
#           2008-08-23        2
#           2008-10-09        2
#                            ..
# 53736410  2005-10-09        1
#           2007-07-29        1
#           2008-03-05        3
#           2008-04-01        1
#           2008-06-29        1
#           2009-05-11        1
#           2010-01-20        1
#           2010-01-26        0
#           2012-02-02        1
# 53736412  2014-02-16        2
# 53736413  2012-11-30        3
# 53736414  2006-09-08        2
#           2006-11-02        2
# 53736415  2014-06-30        1
# 53736417  2014-01-26        4
#           2014-03-09        1
#           2014-04-23        3
# 53736419  2011-04-12        1
# 53736420  2008-09-18        1
# 53736421  2008-09-02        4
#           2010-02-07        1
#           2010-02-15        1
#           2010-11-21        3
#           2012-02-10        3
#           2013-10-14        1
#           2014-03-31        4
#           2014-04-07        1
#           2014-04-12        3
#           2015-05-21        3
# 53736422  2006-04-21        8
# Name: Transfer, Length: 21168, dtype: int64

# %%
adt_cms_admits[~(adt_cms_admits.Readmit_time < datetime.timedelta(days = 0))].shape
# Out:
# (21123, 10)

# %%
adt_cms.groupby(by=['RUID','Admission_date'])
# could also look at which service codes occurred for each visit?
# if we do this we can mostly eliminate the double admit problem
# do we also want to look at all indications/problems for a given visit?
# ANSWERED: No, SVC is probably collinear with other information we have, so let's not worry about it.
# Out:
# 0          4.0
# 1          4.0
# 2          4.0
# 3          4.0
# 4          5.0
# 5          5.0
# 6          5.0
# 7          5.0
# 8          5.0
# 9          3.0
# 10         3.0
# 11         3.0
# 12         4.0
# 13         4.0
# 14         4.0
# 15         4.0
# 16         3.0
# 17         3.0
# 18         3.0
# 19         3.0
# 20         3.0
# 21         3.0
# 22         6.0
# 23         6.0
# 24         6.0
# 25         6.0
# 26         6.0
# 27         6.0
# 28         3.0
# 29         3.0
#           ...
# 121498     3.0
# 121499     6.0
# 121500     6.0
# 121501     6.0
# 121502     6.0
# 121503     6.0
# 121504     6.0
# 121505     3.0
# 121506     3.0
# 121507     3.0
# 121508     5.0
# 121509     5.0
# 121510     5.0
# 121511     5.0
# 121512     5.0
# 121513     5.0
# 121514     5.0
# 121515     5.0
# 121516     5.0
# 121517     5.0
# 121518    10.0
# 121519    10.0
# 121520    10.0
# 121521    10.0
# 121522    10.0
# 121523    10.0
# 121524    10.0
# 121525    10.0
# 121526    10.0
# 121527    10.0
# Name: SRV_CODE, Length: 87076, dtype: float64

# %% [markdown]
# ## (Attempting to) Impute missing discharge dates from CPT hospitalization & discharge codes

# %%
hosp_ed_cpts = ["99217", "99218", "99219", "99220", "99221", "99222", "99223", "99224", "99225", "99226", "99231", "99232", "99233", "99234", "99235", "99236", "99238", "99239", "99251", "99252", "99253", "99254", "99255", "99289","99290", "99291", "99292", "99293", "99294", "99295","99296", "99297", "99356", "99357", "99358", "99359", "99433", "99435", "99460", "99461", "99462", "99463", "99466", "99467", "99468", "99469","99471", "99472", "99475", "99476", "99477", "99478", "99479", "99480", "99485", "99486", "99281", "99282", "99283", "99284", "99285"]
cpt_pat = "|".join(hosp_ed_cpts)
disch_pat = "|".join(["99217", "99238", "99239"])

# %%
cpt_hosp = cpt[cpt.CPT_Code.str.match(cpt_pat)].sort_values(by=['RUID','Event_date','CPT_Code'])

# %%
missing_discharge = adt_cms[(adt_cms.Event == "Admit") & (adt_cms.DISCHARGE_DATE.isnull())].copy().reset_index()
missing_discharge['IMPUTED_DISCHARGE'] = missing_discharge.DISCHARGE_DATE
missing_discharge.head()
# Out:
#    index      RUID  Event Admission_date Event_Date SRV_CODE  \
# 0   1757  50141473  Admit     2015-06-26 2015-06-26      GMD
# 1   2000  51319626  Admit     2013-11-19 2013-11-19      ORT
# 2   2257  52765702  Admit     2014-12-05 2014-12-05      GMD
# 3   2507  53719335  Admit     2014-09-15 2014-09-15      EMR
# 4   2841  53725969  Admit     2011-09-27 2011-09-27      EMR
#
#                         CHIEF_COMPLAINT DISCHARGE_DATE IMPUTED_DISCHARGE
# 0                                 DETOX            NaT               NaT
# 1                         716.17/996.78            NaT               NaT
# 2                             BACK PAIN            NaT               NaT
# 3  INTRACTABLE VOMITING AND DEHYDRATION            NaT               NaT
# 4                                   SOB            NaT               NaT

# %%
for idx, row in missing_discharge.iterrows():
    cpt_sub = cpt_hosp[(cpt_hosp.RUID == row.RUID) & (cpt_hosp.Event_date > row.Admission_date)]
    cpt_disch = cpt_sub[cpt_sub.CPT_Code.str.match(disch_pat)]
    orig_idx = row.index
    
    if cpt_disch.shape[0]:
        missing_discharge.IMPUTED_DISCHARGE[idx] = cpt_disch.iloc[0,2]
        # this will modify the original df
        # but we should probable be careful about that
        # so i'm commenting it out
        # adt_cms.DISCHARGE_DATE[orig_idx] = cpt_disch.iloc[0,2]

# find gaps in CPT codes -- use the last code before a non-contiguous gap and put in as discharge codes
# Out:
# /Users/kkondratieff/anaconda/envs/bios8366/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
missing_discharge
# this isn't a reliable way of doing this -- sometimes there aren't any discharge codes for a given admit so it picks one several months later
# Out:
#       index      RUID  Event Admission_date Event_Date SRV_CODE  \
# 0      1757  50141473  Admit     2015-06-26 2015-06-26      GMD
# 1      2000  51319626  Admit     2013-11-19 2013-11-19      ORT
# 2      2257  52765702  Admit     2014-12-05 2014-12-05      GMD
# 3      2507  53719335  Admit     2014-09-15 2014-09-15      EMR
# 4      2841  53725969  Admit     2011-09-27 2011-09-27      EMR
# 5      2960  53727824  Admit     2013-11-13 2013-11-13      VAS
# 6      4022  53727917  Admit     2012-06-17 2012-06-17      ORT
# 7      5575  53728030  Admit     2015-08-12 2015-08-12      EMR
# 8      6714  53728118  Admit     2015-02-03 2015-02-03      CAR
# 9      7533  53728161  Admit     2014-10-29 2014-10-29      CAR
# 10     7727  53728183  Admit     2011-04-03 2011-04-03      CAR
# 11    11127  53728399  Admit     2013-05-03 2013-05-03      CAR
# 12    11658  53728436  Admit     2015-05-07 2015-05-07      CAR
# 13    11787  53728446  Admit     2015-04-24 2015-04-24      PUL
# 14    12015  53728463  Admit     2013-12-27 2013-12-27      PUL
# 15    12627  53728502  Admit     2009-09-01 2009-09-01      ORT
# 16    14437  53728607  Admit     2014-12-13 2014-12-13      GMD
# 17    15090  53728652  Admit     2014-01-26 2014-01-26      PUL
# 18    15092  53728652  Admit     2014-02-17 2014-02-17      PUL
# 19    15135  53728653  Admit     2014-12-19 2014-12-19      GMD
# 20    15508  53728680  Admit     2013-11-21 2013-11-21      GMD
# 21    15778  53728709  Admit     2015-10-09 2015-10-09      PUL
# 22    15942  53728731  Admit     2014-10-08 2014-10-08      CAR
# 23    17409  53728835  Admit     2015-02-19 2015-02-19      PED
# 24    18065  53728894  Admit     2015-02-01 2015-02-01      GMD
# 25    18402  53728907  Admit     2014-09-26 2014-09-26      CAR
# 26    18729  53728935  Admit     2014-12-20 2014-12-20      GMD
# 27    19293  53728965  Admit     2014-06-01 2014-06-01      OBS
# 28    20974  53729088  Admit     2014-09-07 2014-09-07      ONC
# 29    21194  53729110  Admit     2015-04-04 2015-04-04      PUL
# ..      ...       ...    ...            ...        ...      ...
# 146  101356  53735015  Admit     2014-05-13 2014-05-13      CAR
# 147  101894  53735060  Admit     2014-11-14 2014-11-14      GMD
# 148  102642  53735126  Admit     2014-09-20 2014-09-20      PUL
# 149  103700  53735169  Admit     2014-06-06 2014-06-06      NEP
# 150  105059  53735240  Admit     2015-07-26 2015-07-26      CAR
# 151  105405  53735270  Admit     2013-06-23 2013-06-23      CAR
# 152  105426  53735270  Admit     2013-12-22 2013-12-22      CAR
# 153  105587  53735287  Admit     2013-10-18 2013-10-18      ORT
# 154  105596  53735287  Admit     2014-02-13 2014-02-13      GMD
# 155  105601  53735287  Admit     2014-12-18 2014-12-18      GMD
# 156  108616  53735533  Admit     2015-01-27 2015-01-27      OES
# 157  109043  53735551  Admit     2015-03-15 2015-03-15      GMD
# 158  109951  53735626  Admit     2014-12-02 2014-12-02      CSX
# 159  111545  53735772  Admit     2014-09-13 2014-09-13      GMD
# 160  112295  53735842  Admit     2015-04-12 2015-04-12      CAR
# 161  113028  53735898  Admit     2014-06-20 2014-06-20      NEU
# 162  113643  53735941  Admit     2013-12-23 2013-12-23      INF
# 163  113687  53735943  Admit     2015-03-08 2015-03-08      CSX
# 164  114060  53735975  Admit     2014-08-15 2014-08-15      CAR
# 165  115155  53736031  Admit     2012-10-05 2012-10-05      CSX
# 166  115540  53736048  Admit     2015-11-02 2015-11-02      GMD
# 167  115659  53736054  Admit     2013-08-06 2013-08-06      CAR
# 168  115683  53736054  Admit     2014-02-04 2014-02-04      CAR
# 169  115689  53736054  Admit     2014-04-28 2014-04-28      CAR
# 170  116696  53736117  Admit     2008-10-07 2008-10-07      CAR
# 171  118329  53736229  Admit     2014-10-09 2014-10-09      CAR
# 172  118338  53736230  Admit     2009-06-11 2009-06-11      PLS
# 173  119833  53736308  Admit     2015-05-15 2015-05-15      GMD
# 174  121429  53736417  Admit     2014-03-02 2014-03-02      HEP
# 175  121434  53736417  Admit     2014-04-14 2014-04-14      GAS
#
#                                        CHIEF_COMPLAINT DISCHARGE_DATE  \
# 0                                                DETOX            NaT
# 1                                        716.17/996.78            NaT
# 2                                            BACK PAIN            NaT
# 3                 INTRACTABLE VOMITING AND DEHYDRATION            NaT
# 4                                                  SOB            NaT
# 5          453.40 ACUTE VENOUS EMBOLISM AND THROMBOSIS            NaT
# 6    813.23 RADIUS WITH ULNA; FRACTURE OF AND ULNA ...            NaT
# 7     AIDS ENTEROPATHY; FAILURE TO THRIVE; DEHYDRATION            NaT
# 8                   HYPERTENSIVE EMERGENCY; CHEST PAIN            NaT
# 9                       VOLUME OVERLOAD  HEART FAILURE            NaT
# 10                                CHEST PAIN; S/P CABG            NaT
# 11                                               428.0            NaT
# 12                                                  CP            NaT
# 13                                           PNEUMONIA            NaT
# 14                                               COUGH            NaT
# 15                   ANKYLOSIS OF ANKLE AND FOOT JOINT            NaT
# 16                                                HCAP            NaT
# 17                                          CHEST PAIN            NaT
# 18                                   COPD EXACERBATION            NaT
# 19       FALL; SUBDURAL HEMATOMA; DVT; SPINE FRACTURES            NaT
# 20                                            DELIRIUM            NaT
# 21                                         HYPOTENSION            NaT
# 22                               PACEMAKER MALFUNCTION            NaT
# 23                 VOMITING ; SYNCOPE HEPATITIS/EXPECT            NaT
# 24                                           INFECTION            NaT
# 25                                          CHEST PAIN            NaT
# 26                                           UROSEPSIS            NaT
# 27                                            CIRCLAGE            NaT
# 28                                             SYNCOPE            NaT
# 29                                              ANEMIA            NaT
# ..                                                 ...            ...
# 146                                        CRYOBALLOON            NaT
# 147                                                UTI            NaT
# 148                            FEVER; NAUSEA; VOMITING            NaT
# 149                                      SHOULDER PAIN            NaT
# 150                                         CHEST PAIN            NaT
# 151                                         CHEST PAIN            NaT
# 152                               425.4 CARDIOMYOPATHY            NaT
# 153                                          BACK PAIN            NaT
# 154                                  COUGHING UP BLOOD            NaT
# 155                                               EVAL            NaT
# 156                                       POST OP COMP            NaT
# 157                                               COPD            NaT
# 158  746.4 OTHER CONGENITAL ANOMALIES OF HEART CONG...            NaT
# 159                                                N/V            NaT
# 160                                             414.01            NaT
# 161                                             STROKE            NaT
# 162                                      OSTEOMYELITIS            NaT
# 163                                        TACHYCARDIA            NaT
# 164                                       427.31 A FIB            NaT
# 165                 HEART FAILURE CONGESTIVE; UNSPECI.            NaT
# 166                                           ABD PAIN            NaT
# 167                  FEVER IN HEART TRANSPLANT PATIENT            NaT
# 168    996.83 HEART; COMPLICATIONS PECULIAR TO CERTAIN            NaT
# 169                               HEART TRANSPLANT N/V            NaT
# 170                   VENTRICULAR FIBRILLATION  427.41            NaT
# 171                       ISCHEMIC HEART DISEASE-414.9            NaT
# 172                                    DECUBITUS ULCER            NaT
# 173                                           ABD PAIN            NaT
# 174                                            ASCITES            NaT
# 175                              SIRS; ABD PAIN; N/V/D            NaT
#
#     IMPUTED_DISCHARGE
# 0          2015-07-18
# 1                 NaT
# 2          2014-12-08
# 3          2015-01-10
# 4                 NaT
# 5                 NaT
# 6                 NaT
# 7                 NaT
# 8                 NaT
# 9          2015-04-02
# 10         2011-04-06
# 11         2013-05-05
# 12                NaT
# 13                NaT
# 14         2014-03-01
# 15         2010-02-22
# 16         2014-12-17
# 17         2014-01-28
# 18         2014-02-19
# 19                NaT
# 20         2013-11-24
# 21                NaT
# 22                NaT
# 23         2015-02-20
# 24                NaT
# 25         2014-09-28
# 26         2014-12-25
# 27         2014-06-03
# 28         2014-09-08
# 29                NaT
# ..                ...
# 146        2014-05-14
# 147        2014-11-17
# 148               NaT
# 149        2014-06-07
# 150        2015-07-29
# 151        2013-06-24
# 152        2014-01-18
# 153        2013-11-02
# 154        2014-11-20
# 155               NaT
# 156               NaT
# 157               NaT
# 158               NaT
# 159        2014-10-10
# 160        2015-08-08
# 161        2014-06-21
# 162        2013-12-27
# 163        2015-05-25
# 164               NaT
# 165        2012-12-23
# 166               NaT
# 167        2013-08-08
# 168        2014-02-07
# 169        2014-10-14
# 170        2008-11-21
# 171               NaT
# 172               NaT
# 173        2015-05-17
# 174        2014-03-13
# 175        2014-04-16
#
# [176 rows x 9 columns]
