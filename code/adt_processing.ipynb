# %% [markdown]
# ## To Do
#
# - ~~Finish transfer counts variable (after recoding suspect transfers)~~
# - ~~Get rid of double admits w/ differing service codes~~
# - ~~Rename all column variables to lower case~~
# - ~~Expand out the final patient data frame with visit ids & rows per each day in the hospital~~
# - ~~Get final table of RUIDs that remain in the dataset~~
#
# - Clean up pipeline for creating final leftmost table
#     - Import RUID as a string
#     - Adjust column names on import
#     - Restructure joins so there only needs to be one join->reset_index step
#
#
# - Analyze how much of a difference recoded transfers make?
# - Properly characterize missingness based on dropped discharge dates
# - Properly characterize amount of data loss with each cohort change
#
# Shape of final table:
#
# | ruid | visit_id | admit_date | discharge_date | hospital_day | n_transfers | stay_length | readmit_time | readmit_30d |
# |------|----------|------------|----------------|--------------|-------------|-------------|--------------|-------------|
# | user id | hospital stay # | date admitted | date discharged | date in hospital | number of transfers | duration of stay | time from last discharge to this admission | was the patient a 30d readmit? |
#
#
# ## Nice-to-do
#
# - Construct missing discharge/admit dates from CPT codes (as above) -- do not do this for events where both are missing as these may be ER visits w/o admit, but do check if they fall in the range of an existing stay
# - Characterize the amount of missingness of entire hospital visits from CPT codes

# %% [markdown]
# ## Loading data

# %%
# %ls ../data
# Out:
# FONNESBECK_ADT_20151202.csv        FONNESBECK_LAB_20151202.csv*
# FONNESBECK_BMI_20151202.csv*       FONNESBECK_MED_20151202.csv*
# FONNESBECK_BP_20151202.csv*        FONNESBECK_phenotype_20151202.csv*
# FONNESBECK_CPT_20151202.csv*       Fonnesbeck_DD_2014102014.xlsx
# FONNESBECK_EGFR_20151202.csv*      adt_cms_final.pkl
# FONNESBECK_ICD9_20151202.csv*

# %%
import pandas as pd
import datetime
import numpy as np

# %%
adt = pd.read_table('../data/FONNESBECK_ADT_20151202.csv', encoding='latin1', sep = ',', infer_datetime_format=True, parse_dates=['Admission_date','Event_Date','DISCHARGE_DATE'])
pheno = pd.read_table('../data/FONNESBECK_phenotype_20151202.csv', encoding='latin1', sep = ',', infer_datetime_format=True, parse_dates=['DOB','DOD'])
cpt = pd.read_table('../data/FONNESBECK_CPT_20151202.csv', encoding='latin1', sep = ',', infer_datetime_format=True, parse_dates=['Event_date'])
# import RUID as a string, rename columns

# %%
svc = pd.read_excel('../data/FONNESBECK_DD_2014102014.xlsx',sheet_name='Service code', sep = ',')
svc.rename(columns = {"Service Code":"SVC", "Service Code Desc":"Desc"}, inplace = True)

# %%
adt.Event = pd.Categorical(adt.Event,categories = ['Admit','Transfer','Discharge'])
adt = adt.sort_values(by = ['RUID','Admission_date','Event','Event_Date']).reset_index(drop = True)

# %%
adt.describe(include='all')
# Out:
#                 RUID     Event       Admission_date           Event_Date  \
# count   1.215300e+05    121530               119969               121530
# unique           NaN         3                 4192                 4279
# top              NaN  Transfer  2013-03-14 00:00:00  2013-12-28 00:00:00
# freq             NaN     61636                  111                   69
# first            NaN       NaN  2004-01-28 00:00:00  2004-01-28 00:00:00
# last             NaN       NaN  2015-11-26 00:00:00  2015-11-26 00:00:00
# mean    5.366861e+07       NaN                  NaN                  NaN
# std     4.628206e+05       NaN                  NaN                  NaN
# min     5.013526e+07       NaN                  NaN                  NaN
# 25%     5.372980e+07       NaN                  NaN                  NaN
# 50%     5.373203e+07       NaN                  NaN                  NaN
# 75%     5.373430e+07       NaN                  NaN                  NaN
# max     5.373642e+07       NaN                  NaN                  NaN
#
#        SRV_CODE CHIEF_COMPLAINT       DISCHARGE_DATE
# count    121530          120603               119472
# unique       73           13118                 4195
# top         GMD          296.90  2010-12-23 00:00:00
# freq      13062            2394                  111
# first       NaN             NaN  2004-02-11 00:00:00
# last        NaN             NaN  2015-11-23 00:00:00
# mean        NaN             NaN                  NaN
# std         NaN             NaN                  NaN
# min         NaN             NaN                  NaN
# 25%         NaN             NaN                  NaN
# 50%         NaN             NaN                  NaN
# 75%         NaN             NaN                  NaN
# max         NaN             NaN                  NaN

# %% [markdown]
# ## Looking at missingness

# %%
adt.isnull().sum()/adt.shape[0]
# Out:
# RUID               0.000000
# Event              0.000000
# Admission_date     0.012845
# Event_Date         0.000000
# SRV_CODE           0.000000
# CHIEF_COMPLAINT    0.007628
# DISCHARGE_DATE     0.016934
# dtype: float64

# %%
adt[adt.Admission_date.isnull() & adt.DISCHARGE_DATE.isnull()].SRV_CODE.value_counts() # may correspond to ER visits without admission which we don't need to predict
# Out:
# CAR    295
# GMD    269
# PED    110
# NEP     69
# GER     55
# PUL     51
# GNS     46
# OBS     45
# ORT     43
# INF     40
# NES     38
# ONC     37
# PGS     37
# HEM     34
# PON     34
# URO     32
# NEU     31
# GAS     23
# EMR     22
# OTO     20
# TRA     20
# HEP     17
# PLS     16
# EGS     15
# PCC     14
# PGA     14
# LTS     14
# PNP     11
# BRN     10
# PCA     10
# PNE      9
# PPU      9
# RTS      8
# CSX      8
# VAS      7
# PSY      6
# PEN      5
# GIL      4
# GYN      4
# OES      4
# CLP      3
# DIA      3
# ADO      2
# RAD      2
# GEN      2
# CTS      2
# PTA      2
# THS      2
# NEO      2
# RHM      1
# Name: SRV_CODE, dtype: int64

# %%
adt[(adt.Admission_date.isnull() & adt.DISCHARGE_DATE.isnull())].shape # may correspond to ER visits without admission which we don't need to predict
# Out:
# (1557, 7)

# %%
adt[adt.Admission_date.isnull()].Event.value_counts()
# Out:
# Transfer     1559
# Discharge       2
# Admit           0
# Name: Event, dtype: int64

# %%
adt[adt.DISCHARGE_DATE.isnull()].Event.value_counts()
# Out:
# Transfer     1860
# Admit         198
# Discharge       0
# Name: Event, dtype: int64

# %%
adt[(adt.Admission_date.isnull()) & (adt.Event == 'Discharge')]
# Out:
#            RUID      Event Admission_date Event_Date SRV_CODE CHIEF_COMPLAINT  \
# 76409  53733158  Discharge            NaT 2007-08-06      TRA            STAT
# 76578  53733172  Discharge            NaT 2013-02-17      PED          SEPSIS
#
#       DISCHARGE_DATE
# 76409     2007-08-06
# 76578     2013-02-17

# %%
adt[76400:76420]
# Out:
#            RUID      Event Admission_date Event_Date SRV_CODE  \
# 76400  53733157      Admit     2012-02-14 2012-02-14      PUL
# 76401  53733157   Transfer     2012-02-14 2012-02-14      PUL
# 76402  53733157  Discharge     2012-02-14 2012-02-15      PUL
# 76403  53733157      Admit     2012-04-14 2012-04-14      ONC
# 76404  53733157   Transfer     2012-04-14 2012-04-14      ONC
# 76405  53733157  Discharge     2012-04-14 2012-04-15      ONC
# 76406  53733157   Transfer            NaT 2011-11-21      ONC
# 76407  53733157   Transfer            NaT 2011-11-21      HEM
# 76408  53733158   Transfer            NaT 2007-08-05      TRA
# 76409  53733158  Discharge            NaT 2007-08-06      TRA
# 76410  53733159      Admit     2007-03-08 2007-03-08      PON
# 76411  53733159   Transfer     2007-03-08 2007-03-08      PON
# 76412  53733159  Discharge     2007-03-08 2007-03-10      PON
# 76413  53733159      Admit     2007-03-15 2007-03-15      PON
# 76414  53733159   Transfer     2007-03-15 2007-03-15      PON
# 76415  53733159  Discharge     2007-03-15 2007-03-17      PON
# 76416  53733159      Admit     2007-08-11 2007-08-11      OTO
# 76417  53733159  Discharge     2007-08-11 2007-08-16      OTO
# 76418  53733159      Admit     2007-09-14 2007-09-14      PON
# 76419  53733159  Discharge     2007-09-14 2007-09-15      PON
#
#                                  CHIEF_COMPLAINT DISCHARGE_DATE
# 76400                                 HEMOPTYSIS     2012-02-15
# 76401                                 HEMOPTYSIS     2012-02-15
# 76402                                 HEMOPTYSIS     2012-02-15
# 76403  FAILURE TO THRIVE; DEHYDRATION; KIDNEY CA     2012-04-15
# 76404  FAILURE TO THRIVE; DEHYDRATION; KIDNEY CA     2012-04-15
# 76405  FAILURE TO THRIVE; DEHYDRATION; KIDNEY CA     2012-04-15
# 76406                                 HEMOPTYSIS            NaT
# 76407                                 HEMOPTYSIS            NaT
# 76408                                       STAT     2007-08-06
# 76409                                       STAT     2007-08-06
# 76410                                  PNEUMONIA     2007-03-10
# 76411                                  PNEUMONIA     2007-03-10
# 76412                                  PNEUMONIA     2007-03-10
# 76413                         SICKLE CELL CRISIS     2007-03-17
# 76414                         SICKLE CELL CRISIS     2007-03-17
# 76415                         SICKLE CELL CRISIS     2007-03-17
# 76416        HYPERTROPHY TONSILS/ADENOIDS 474.10     2007-08-16
# 76417        HYPERTROPHY TONSILS/ADENOIDS 474.10     2007-08-16
# 76418                                      FEVER     2007-09-15
# 76419                                      FEVER     2007-09-15

# %% [markdown]
# ## Adding age data & removing pediatric patients

# %%
adt_age = pd.merge(adt,pheno)
# admits = adt_age.Admission_date.dt
events = adt_age.Event_Date.dt
birthdays = adt_age.DOB.dt

adt_age['age'] = events.year - birthdays.year + ((events.month < birthdays.month) & (events.day < birthdays.day))
# above from https://stackoverflow.com/questions/2217488/age-from-birthdate-in-python/9754466#9754466

# %%
# getting rid of peds & psychiatric patients...
# we're removing these because they aren't part of the CMS criteria so 30-day readmits for them don't lose the hospital money
ped_svc = '|'.join(svc.SVC[svc.Desc.str.contains("CHILD|PED")])
psych_svc = '|'.join(svc.SVC[svc.Desc.str.contains("PSYCH")])

# ped_filter = ((adt_age.age < 18) | (adt_age.SRV_CODE.str.contains(ped_svc)) & ~((adt_age.age > 35) & (adt_age.SRV_CODE.str.contains(ped_svc))))
# the ~ condition here contains a handful of rows that I think are coding errors -- very old patients admitted to pediatric services
# the cutoff is 35 because some pediatric cancer/cardiac/etc patients will continue with pediatric services for their original condition into adulthood

ped_filter = (adt_age.age < 18)
psych_filter = (adt_age.SRV_CODE.str.contains(psych_svc))

# doing this the simplest way possible
# the psych filter will remove patients with a primary psych admit, which removes them from our consideration, but NOT patients who have psych consults
# may want to explicitly do that

# %%
adt_cms = adt[~(ped_filter | psych_filter)].copy()

# %% [markdown]
# ## Filtering to admits & eliminating missing discharges

# %%
adt_cms['imputed_transfer'] = [0]*adt_cms.shape[0]
txmask = (adt_cms.Event == "Admit") & (adt_cms.Admission_date != adt_cms.Event_Date) # there are 431 of these

adt_cms.loc[txmask,'Event'] = "Transfer"
adt_cms.loc[txmask,'imputed_transfer'] = 1

# %%
adt_cms[adt_cms.imputed_transfer == 1]
# Out:
#             RUID     Event Admission_date Event_Date SRV_CODE  \
# 461     50135624  Transfer     2015-06-24 2015-06-25      CAR
# 529     50135821  Transfer     2013-10-24 2013-10-27      GMD
# 1574    50139667  Transfer     2014-10-02 2014-10-03      CAR
# 1769    50141958  Transfer     2014-03-11 2014-03-12      PUL
# 1805    50142794  Transfer     2014-08-11 2014-08-12      CAR
# 2490    53719335  Transfer     2014-04-24 2014-04-25      GMD
# 2519    53719335  Transfer     2015-03-01 2015-03-02      GMD
# 2530    53719335  Transfer     2015-04-02 2015-04-04      GMD
# 2551    53719857  Transfer     2014-08-25 2014-08-26      GMD
# 2810    53725468  Transfer     2014-11-14 2014-11-15      PUL
# 3039    53727830  Transfer     2013-12-25 2013-12-26      ORT
# 3202    53727848  Transfer     2014-02-01 2014-02-04      GMD
# 3304    53727859  Transfer     2014-04-21 2014-04-22      GMD
# 3996    53727911  Transfer     2014-05-21 2014-05-23      PUL
# 4018    53727915  Transfer     2014-02-09 2014-02-10      TRA
# 4160    53727932  Transfer     2014-07-21 2014-07-22      URO
# 4519    53727968  Transfer     2015-01-07 2015-01-08      CAR
# 4767    53727986  Transfer     2014-04-07 2014-04-08      GAS
# 5557    53728030  Transfer     2015-02-22 2015-02-23      INF
# 5641    53728036  Transfer     2014-10-05 2014-10-06      INF
# 6147    53728072  Transfer     2014-11-17 2014-11-18      PGS
# 6827    53728131  Transfer     2013-12-25 2013-12-26      OBS
# 6849    53728132  Transfer     2014-01-15 2014-01-16      CSX
# 7048    53728143  Transfer     2013-08-11 2013-08-12      GAS
# 7142    53728145  Transfer     2014-09-10 2014-09-11      NES
# 7231    53728152  Transfer     2014-05-25 2014-05-26      CAR
# 7524    53728161  Transfer     2014-06-29 2014-06-30      GMD
# 7580    53728169  Transfer     2014-01-03 2014-01-05      CSX
# 7629    53728173  Transfer     2014-08-25 2014-08-26      CAR
# 8015    53728206  Transfer     2013-07-16 2013-07-17      CAR
# ...          ...       ...            ...        ...      ...
# 113355  53735918  Transfer     2014-03-29 2014-03-31      CAR
# 113629  53735941  Transfer     2013-06-21 2013-06-22      CAR
# 114051  53735975  Transfer     2014-05-30 2014-05-31      CAR
# 114057  53735975  Transfer     2014-06-19 2014-06-21      CAR
# 114080  53735977  Transfer     2014-02-16 2014-02-17      HEM
# 114264  53735988  Transfer     2015-05-10 2015-05-12      GMD
# 114629  53736000  Transfer     2014-05-23 2014-05-24      GMD
# 115485  53736045  Transfer     2014-05-29 2014-05-31      GMD
# 115497  53736045  Transfer     2014-08-20 2014-08-21      GMD
# 115776  53736063  Transfer     2014-03-19 2014-03-20      CAR
# 116048  53736080  Transfer     2015-07-21 2015-07-22      GMD
# 116059  53736080  Transfer     2015-09-05 2015-09-06      INF
# 116215  53736090  Transfer     2015-06-27 2015-06-28      CAR
# 116370  53736095  Transfer     2014-09-06 2014-09-07      ONC
# 117908  53736206  Transfer     2014-02-01 2014-02-02      PGA
# 118100  53736214  Transfer     2013-03-29 2013-04-01      NES
# 118494  53736237  Transfer     2013-07-29 2013-07-30      GMD
# 118623  53736242  Transfer     2013-12-17 2013-12-18      CAR
# 118838  53736262  Transfer     2015-05-03 2015-05-04      CAR
# 119400  53736286  Transfer     2014-03-14 2014-03-15      HEM
# 119441  53736286  Transfer     2014-10-26 2014-10-29      HEM
# 119543  53736290  Transfer     2014-10-12 2014-10-13      CAR
# 119647  53736299  Transfer     2014-06-22 2014-06-25      NEP
# 119828  53736308  Transfer     2014-12-12 2014-12-14      CAR
# 120285  53736327  Transfer     2015-05-25 2015-05-26      NEP
# 120625  53736349  Transfer     2015-01-19 2015-01-20      CAR
# 120637  53736350  Transfer     2015-09-13 2015-09-14      GMD
# 120875  53736369  Transfer     2014-06-27 2014-06-28      BRN
# 120979  53736379  Transfer     2014-02-03 2014-02-04      GMD
# 121381  53736415  Transfer     2014-06-30 2014-07-01      CAR
#
#                                           CHIEF_COMPLAINT DISCHARGE_DATE  \
# 461                                                   SOB     2015-06-28
# 529                                               LEG LAC     2013-10-29
# 1574                                     CHF EXACERBATION     2014-10-22
# 1769                                               TRAUMA     2014-03-13
# 1805                                                  CHF     2014-08-18
# 2490                                             GI BLEED     2014-04-25
# 2519                                                  PNA     2015-03-04
# 2530                                                  N/V     2015-04-13
# 2551                                               HYPERK     2014-08-27
# 2810                     S/P LIVER TXPLANT; RENAL FAILURE     2014-11-27
# 3039                                             CSF LEAK     2013-12-30
# 3202                                                 RASH     2014-02-04
# 3304                                                  AMS     2014-04-27
# 3996                                                  ACS     2014-05-29
# 4018                                                  GSW     2014-02-10
# 4160                                     DEVICE INFECTION     2014-07-22
# 4519                               ACUTE BLOOD LOSE-ANIMA     2015-01-08
# 4767                          UREMIA; AKI; N/V; LIVER TXP     2014-04-09
# 5557                    UNCONTROLLED PAIN; ABD DISTENTION     2015-02-24
# 5641                                                FEVER     2014-10-09
# 6147                                     PYLORIC STENOSIS     2014-11-20
# 6827                                                 FALL     2013-12-29
# 6849                                    HEMATEMESIS; LVAD     2014-01-20
# 7048                                      RECTAL BLEEDING     2013-08-16
# 7142                                             HEADACHE     2014-09-25
# 7231    FEVER; CARDIOMYOPATHY W/INDWELLING C-PULSE DEVICE     2014-05-30
# 7524                                            UROSEPSIS     2014-07-03
# 7580                                                  CHF     2014-01-17
# 7629                             CONGESTIVE HEART FAILURE     2014-09-01
# 8015                                              GENERAL     2013-07-18
# ...                                                   ...            ...
# 113355                                                 CP     2014-03-31
# 113629                                              424.0     2013-06-29
# 114051                        ATRIAL FIBRILLATION--427.31     2014-06-07
# 114057                                        HEART ISSUE     2014-06-21
# 114080                                           LYMPHOMA     2014-02-24
# 114264  MID EPIGASTRIC ABD PAIN; DEHYDRATION; HYPERGLY...     2015-05-16
# 114629                                                PNA     2014-05-30
# 115485                      ALCOHOL WITHDRAWAL; GI BLEED;     2014-06-06
# 115497                                  COPD EXACERBATION     2014-08-28
# 115776                                                CHF     2014-03-25
# 116048                                            ABSCESS     2015-07-30
# 116059  H/O PARAVERTEBRAL ABSCESS; BILAT PSOAS ABSCESS...     2015-09-07
# 116215                                         HEART CATH     2015-07-01
# 116370                    HYPERCALCEMIA; MYLTIPLE MYELOMA     2014-09-12
# 117908                                     VOMITING BLOOD     2014-02-04
# 118100         OTHER SPEC DEFORMITY ACQ DEFORMITY OF HEAD     2013-04-30
# 118494                                               PAIN     2013-07-31
# 118623                                428.9 HEART FAILURE     2013-12-26
# 118838                                                 CP     2015-05-04
# 119400                                                SCC     2014-03-19
# 119441                                               PAIN     2014-11-07
# 119543                                         CHEST PAIN     2014-10-24
# 119647                                                AKI     2014-07-15
# 119828                                             NSTEMI     2014-12-16
# 120285                                    VOMITING/XPLANT     2015-06-01
# 120625     NSTEMI; ABDOMIANL PAIN; MALIGNANT HYPERTENSION     2015-01-21
# 120637                                            SYNCOPE     2015-09-27
# 120875              GRAFT-VERSUS-HOSTDISEASE-279.50/948.2     2014-07-12
# 120979                                           SEIZURES     2014-02-09
# 121381                                       427.31 A FIB     2014-07-01
#
#         imputed_transfer
# 461                    1
# 529                    1
# 1574                   1
# 1769                   1
# 1805                   1
# 2490                   1
# 2519                   1
# 2530                   1
# 2551                   1
# 2810                   1
# 3039                   1
# 3202                   1
# 3304                   1
# 3996                   1
# 4018                   1
# 4160                   1
# 4519                   1
# 4767                   1
# 5557                   1
# 5641                   1
# 6147                   1
# 6827                   1
# 6849                   1
# 7048                   1
# 7142                   1
# 7231                   1
# 7524                   1
# 7580                   1
# 7629                   1
# 8015                   1
# ...                  ...
# 113355                 1
# 113629                 1
# 114051                 1
# 114057                 1
# 114080                 1
# 114264                 1
# 114629                 1
# 115485                 1
# 115497                 1
# 115776                 1
# 116048                 1
# 116059                 1
# 116215                 1
# 116370                 1
# 117908                 1
# 118100                 1
# 118494                 1
# 118623                 1
# 118838                 1
# 119400                 1
# 119441                 1
# 119543                 1
# 119647                 1
# 119828                 1
# 120285                 1
# 120625                 1
# 120637                 1
# 120875                 1
# 120979                 1
# 121381                 1
#
# [431 rows x 8 columns]

# %%
adt_cms_admits = adt_cms[(adt_cms.Event == 'Admit') & ~(adt_cms.DISCHARGE_DATE.isnull())].copy().reset_index(drop = True)
# removing missing discharge dates because I can't fix them right now
# adt_cms[(adt_cms.Event == 'Admit') & (adt_cms.DISCHARGE_DATE.isnull())]

# adt_cms_admits = adt_cms_admits[adt_cms_admits.Admission_date == adt_cms_admits.Event_Date].reset_index(drop = True)
# this removes admits that aren't the same day as the admit date
# i'm not sure what these actually are--they might be miscoded transfers or admissions to another department

# %% [markdown]
# ## Constructing variables

# %%
adt_cms_admits['stay_length'] = adt_cms_admits.DISCHARGE_DATE - adt_cms_admits.Admission_date
adt_cms_admits['readmit_time'] = adt_cms_admits.Admission_date - adt_cms_admits.DISCHARGE_DATE.shift()

didx = ~(adt_cms_admits.RUID.shift() == adt_cms_admits.RUID)

adt_cms_admits['readmit_time'] = adt_cms_admits['readmit_time'].mask(didx)

adt_cms_admits['readmit_30d'] = np.where(adt_cms_admits.readmit_time <= datetime.timedelta(days=30),1,0)
adt_cms_admits = adt_cms_admits[~(adt_cms_admits.readmit_time < datetime.timedelta(days=0))] # get rid of double admits where we had a different
# chief complaint or svc code

# %%
adt_cms_admits.shape # we now have 21123 admissions to work with
# Out:
# (21123, 11)

# %%
event_counts = (adt_cms[~(adt_cms.DISCHARGE_DATE.isnull())].groupby(by=['RUID','Admission_date'])
                .Event
                .value_counts(sort=False)
                .unstack(fill_value = 0))

n_transfers = event_counts['Transfer'] # now pull the number of transfers and we're good
# merge this by multindex onto the other table once it's cleaned & ready to go

# %%
adt_cms_admits2 = (adt_cms_admits.drop(labels=['Event','Event_Date','SRV_CODE','imputed_transfer','CHIEF_COMPLAINT'], axis = 1)
                  .set_index(['RUID','Admission_date'])
                  .join(n_transfers)
                  .reset_index(drop = False)
                  .rename({'RUID': 'ruid', 'Admission_date': 'admit_date', 'DISCHARGE_DATE': 'discharge_date', 'Transfer': 'n_transfers'},axis = 1))

# %%
adt_cms_admits2['visit_id'] = adt_cms_admits2.groupby('ruid').cumcount()

# %%
def date_ranger(x):
    start = x.iloc[0]['admit_date']
    end = x.iloc[0]['discharge_date']
    return pd.DataFrame(pd.date_range(start=start, end=end).tolist())

# %%
hospital_day = (adt_cms_admits2.groupby(['ruid','visit_id'])
                .apply(date_ranger)
                .reset_index(drop = False)
                .drop('level_2',axis = 1)
                .set_index(['ruid','visit_id']))

# takes a bit to run

# %%
adt_cms_final = (adt_cms_admits2.set_index(['ruid','visit_id'])
                .join(hospital_day)
                .reset_index(drop = False)
                .rename({0:'hospital_day'},axis=1))[['ruid','visit_id','admit_date','discharge_date','hospital_day',
                                                     'stay_length','n_transfers','readmit_time','readmit_30d']]

# %%
adt_cms_final
# Out:
#             ruid  visit_id admit_date discharge_date hospital_day stay_length  \
# 0       50135262         0 2007-02-08     2007-02-12   2007-02-08      4 days
# 1       50135262         0 2007-02-08     2007-02-12   2007-02-09      4 days
# 2       50135262         0 2007-02-08     2007-02-12   2007-02-10      4 days
# 3       50135262         0 2007-02-08     2007-02-12   2007-02-11      4 days
# 4       50135262         0 2007-02-08     2007-02-12   2007-02-12      4 days
# 5       50135262         1 2007-08-03     2007-08-06   2007-08-03      3 days
# 6       50135262         1 2007-08-03     2007-08-06   2007-08-04      3 days
# 7       50135262         1 2007-08-03     2007-08-06   2007-08-05      3 days
# 8       50135262         1 2007-08-03     2007-08-06   2007-08-06      3 days
# 9       50135262         2 2007-08-28     2007-08-29   2007-08-28      1 days
# 10      50135262         2 2007-08-28     2007-08-29   2007-08-29      1 days
# 11      50135262         3 2008-02-24     2008-02-28   2008-02-24      4 days
# 12      50135262         3 2008-02-24     2008-02-28   2008-02-25      4 days
# 13      50135262         3 2008-02-24     2008-02-28   2008-02-26      4 days
# 128386  53736422         0 2006-04-21     2006-05-05   2006-05-03     14 days
# 128387  53736422         0 2006-04-21     2006-05-05   2006-05-04     14 days
# 128388  53736422         0 2006-04-21     2006-05-05   2006-05-05     14 days
#
#         n_transfers readmit_time  readmit_30d
# 0                 2          NaT            0
# 1                 2          NaT            0
# 2                 2          NaT            0
# 3                 2          NaT            0
# 4                 2          NaT            0
# 5                 3     172 days            0
# 6                 3     172 days            0
# 7                 3     172 days            0
# 8                 3     172 days            0
# 9                 1      22 days            1
# 10                1      22 days            1
# 11                2     179 days            0
# 12                2     179 days            0
# 13                2     179 days            0
# 14                2     179 days            0
# 15                2     179 days            0
# 16                1      44 days            0
# 17                1      44 days            0
# 18                1     928 days            0
# 19                1     928 days            0
# 20                4     105 days            0
# 21                4     105 days            0
# 22                4     105 days            0
# 23                4     105 days            0
# 24                4     105 days            0
# 25                4     105 days            0
# 26                4     105 days            0
# 27                4     105 days            0
# 28                4     105 days            0
# 29                4     105 days            0
# ...             ...          ...          ...
# 128359            1     607 days            0
# 128360            4     167 days            0
# 128361            4     167 days            0
# 128362            4     167 days            0
# 128363            1       5 days            1
# 128364            1       5 days            1
# 128365            3       4 days            1
# 128366            3       4 days            1
# 128367            3       4 days            1
# 128368            3       4 days            1
# 128369            3     401 days            0
# 128370            3     401 days            0
# 128371            3     401 days            0
# 128372            3     401 days            0
# 128373            3     401 days            0
# 128374            8          NaT            0
# 128375            8          NaT            0
# 128376            8          NaT            0
# 128377            8          NaT            0
# 128378            8          NaT            0
# 128379            8          NaT            0
# 128380            8          NaT            0
# 128381            8          NaT            0
# 128382            8          NaT            0
# 128383            8          NaT            0
# 128384            8          NaT            0
# 128385            8          NaT            0
# 128386            8          NaT            0
# 128387            8          NaT            0
# 128388            8          NaT            0
#
# [128389 rows x 9 columns]

# %%
final_ruids = adt_cms_final.ruid.unique()

# %%
len(final_ruids) # from 8000 patients, we're down to 5664.
# Out:
# 5664

# %%
adt_cms_admits2.describe()
# Out:
#                ruid             stay_length              readmit_time  \
# count  2.112300e+04                   21123                     15459
# mean   5.365541e+07  5 days 01:52:33.131657  222 days 06:58:03.330098
# std    5.116519e+05  6 days 15:08:41.550742  408 days 05:35:22.089900
# min    5.013526e+07         0 days 00:00:00           0 days 00:00:00
# 25%    5.372970e+07         2 days 00:00:00          17 days 00:00:00
# 50%    5.373195e+07         3 days 00:00:00          58 days 00:00:00
# 75%    5.373427e+07         6 days 00:00:00         222 days 00:00:00
# max    5.373642e+07       206 days 00:00:00        3775 days 00:00:00
#
#         readmit_30d   n_transfers      visit_id
# count  21123.000000  21123.000000  21123.000000
# mean       0.269327      2.035128      5.632912
# std        0.443621      1.895853     10.275376
# min        0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000
# 50%        0.000000      2.000000      2.000000
# 75%        1.000000      3.000000      6.000000
# max        1.000000     36.000000    104.000000

# %%
adt_cms[adt_cms.RUID == 53736286]
# Out:
#             RUID      Event Admission_date Event_Date SRV_CODE  \
# 119081  53736286      Admit     2007-08-27 2007-08-27      HEM
# 119082  53736286   Transfer     2007-08-27 2007-08-28      HEM
# 119083  53736286   Transfer     2007-08-27 2007-09-02      HEM
# 119440                            PAIN     2014-11-07                 0
# 119441                            PAIN     2014-11-07                 1
# 119442                            PAIN     2014-11-07                 0
# 119443                            PAIN     2014-11-07                 0
# 119444                            PAIN     2014-11-07                 0
# 119445                            PAIN     2014-11-07                 0
# 119446                            PAIN     2014-11-07                 0
# 119447                            PAIN     2014-11-07                 0
# 119448                   SCC; SVC; HSM     2014-11-23                 0
# 119449                   SCC; SVC; HSM     2014-11-23                 0
# 119450                   SCC; SVC; HSM     2014-11-23                 0
# 119451                   SCC; SVC; HSM     2014-11-23                 0
# 119452                   SCC; SVC; HSM     2014-11-23                 0
# 119453         SICKLE CELL PAIN CRISIS            NaT                 0
# 119454                  SS PAIN CRISIS            NaT                 0
#
# [374 rows x 8 columns]

# %%
adt_cms_admits.readmit_30d.sum() # number of events in our final cohort
# Out:
# 5689

# %% [markdown]
# ## (Attempting to) Impute missing discharge dates from CPT hospitalization & discharge codes

# %%
hosp_ed_cpts = ["99217", "99218", "99219", "99220", "99221", "99222", "99223", "99224", "99225", "99226", "99231", "99232", "99233", "99234", "99235", "99236", "99238", "99239", "99251", "99252", "99253", "99254", "99255", "99289","99290", "99291", "99292", "99293", "99294", "99295","99296", "99297", "99356", "99357", "99358", "99359", "99433", "99435", "99460", "99461", "99462", "99463", "99466", "99467", "99468", "99469","99471", "99472", "99475", "99476", "99477", "99478", "99479", "99480", "99485", "99486", "99281", "99282", "99283", "99284", "99285"]
cpt_pat = "|".join(hosp_ed_cpts)
disch_pat = "|".join(["99217", "99238", "99239"])

# %%
cpt_hosp = cpt[cpt.CPT_Code.str.match(cpt_pat)].sort_values(by=['RUID','Event_date','CPT_Code'])

# %%
missing_discharge = adt_cms[(adt_cms.Event == "Admit") & (adt_cms.DISCHARGE_DATE.isnull())].copy().reset_index()
missing_discharge['IMPUTED_DISCHARGE'] = missing_discharge.DISCHARGE_DATE
missing_discharge.head()

# %%
for idx, row in missing_discharge.iterrows():
    cpt_sub = cpt_hosp[(cpt_hosp.RUID == row.RUID) & (cpt_hosp.Event_date > row.Admission_date)]
    cpt_disch = cpt_sub[cpt_sub.CPT_Code.str.match(disch_pat)]
    orig_idx = row.index
    
    if cpt_disch.shape[0]:
        missing_discharge.IMPUTED_DISCHARGE[idx] = cpt_disch.iloc[0,2]
        # this will modify the original df
        # but we should probable be careful about that
        # so i'm commenting it out
        # adt_cms.DISCHARGE_DATE[orig_idx] = cpt_disch.iloc[0,2]

# find gaps in CPT codes -- use the last code before a non-contiguous gap and put in as discharge codes

# %%
missing_discharge
# this isn't a reliable way of doing this -- sometimes there aren't any discharge codes for a given admit so it picks one several months later

# %% [markdown]
# ## Characterizing the population & missingness

# %%
adt.describe(include = "all")
# Out:
#             RUID     Event       Admission_date           Event_Date SRV_CODE  \
# count     121530    121530               119969               121530   121530
# unique      8000         3                 4192                 4279       73
# top     53736286  Transfer  2013-03-14 00:00:00  2013-12-28 00:00:00      GMD
# freq         374     61636                  111                   69    13062
# first        NaN       NaN  2004-01-28 00:00:00  2004-01-28 00:00:00      NaN
# last         NaN       NaN  2015-11-26 00:00:00  2015-11-26 00:00:00      NaN
#
#        CHIEF_COMPLAINT       DISCHARGE_DATE
# count           120603               119472
# unique           13118                 4195
# top             296.90  2010-12-23 00:00:00
# freq              2394                  111
# first              NaN  2004-02-11 00:00:00
# last               NaN  2015-11-23 00:00:00

# %%
adt_age[adt_age.Event == "Admit"].describe()
# this may not be totally meaningful since many patients are in here multiple times & have aged over the course of contact
# with the system
# Out:
#                 age
# count  30199.000000
# mean      39.943210
# std       24.513748
# min        0.000000
# 25%       19.000000
# 50%       41.000000
# 75%       60.000000
# max      102.000000

# %%
len(np.unique(adt_cms.RUID)) - len(np.unique(adt_cms_admits.RUID))
# 381 individuals either have no admit events or have admit events without a discharge date
# Out:
# 381

# %%
peds = set(adt_age.RUID[ped_filter])
psych = set(adt_age.RUID[psych_filter])
final = set(final_ruids)

intpeds = peds.intersection(final)
intpsych = psych.intersection(final)

# %%
print("Starting from a cohort of 8000 patients, there are {fin} patients in the final cohort. ").format(fin=len(final),peds=len(peds),psych=len(psych),inpeds=len(intpeds),intpsych=len(intpsych))
# Out:
# 5664

# %%
len(peds.intersection(final))
# Out:
# 146

# %%
len(psych.intersection(final))
# Out:
# 354

# %%
len(psych.intersection(peds))
# Out:
# 156

# %%
len(psych)
# Out:
# 765

# %%
len(peds)
# Out:
# 2131

# %%
no_bd = set(pheno.RUID[pheno.DOB.isnull()])

# %%
len(no_bd)
# Out:
# 43

# %%
adt_age[(adt_age.age.isnull()) & (adt_age.Event == "Admit") & ((adt_age.SRV_CODE.str.contains(ped_svc)) | (adt_age.SRV_CODE.str.contains("NUR")) | (adt_age.CHIEF_COMPLAINT == "NEWBORN"))].shape
# Out:
# (45, 12)

# %%
adt_age[(adt_age.age.isnull()) & (adt_age.Event == "Admit") & ((adt_age.SRV_CODE.str.contains(ped_svc)) | (adt_age.SRV_CODE.str.contains("NUR")) | (adt_age.CHIEF_COMPLAINT == "NEWBORN"))]
# Out:
#             RUID  Event Admission_date Event_Date SRV_CODE  \
# 6146    53728072  Admit     2014-11-17 2014-11-17      PGS
# 6147    53728072  Admit     2014-11-17 2014-11-18      PGS
# 9140    53728274  Admit     2014-10-10 2014-10-10      PCC
# 9146    53728274  Admit     2015-07-12 2015-07-12      PED
# 12215   53728472  Admit     2015-01-09 2015-01-09      NUR
# 14042   53728579  Admit     2014-11-19 2014-11-19      NUR
# 14390   53728602  Admit     2013-12-19 2013-12-19      NUR
# 15560   53728684  Admit     2014-06-21 2014-06-21      NUR
# 19987   53729008  Admit     2015-01-01 2015-01-01      NUR
# 37721   53730329  Admit     2014-06-07 2014-06-07      NUR
# 47618   53731021  Admit     2014-11-03 2014-11-03      NUR
# 47899   53731050  Admit     2014-12-18 2014-12-18      NUR
# 49572   53731180  Admit     2014-11-10 2014-11-10      NUR
# 51857   53731369  Admit     2014-03-24 2014-03-24      NUR
# 53621   53731518  Admit     2014-01-09 2014-01-09      PED
# 54108   53731561  Admit     2014-03-21 2014-03-21      NEO
# 54118   53731561  Admit     2014-04-10 2014-04-10      PCC
# 54156                      ABDOMINAL DISTENSION     2014-07-13  NaN NaT NaT
# 54162                    PNA; ALLERGIC REACTION     2015-03-16  NaN NaT NaT
# 54163                    PNA; ALLERGIC REACTION     2015-03-16  NaN NaT NaT
# 66252                              PANCREATITIS     2015-02-18  NaN NaT NaT
# 80489                                   NEWBORN     2014-10-13  NaN NaT NaT
# 80552                              BRONCIOLITIS     2014-08-05  NaN NaT NaT
# 80556                                      ALTE            NaT  NaN NaT NaT
# 81376                                 FTT; ALTE     2014-02-23  NaN NaT NaT
# 81377                                 FTT; ALTE     2014-02-23  NaN NaT NaT
# 81381                                  VOMITING     2014-10-03  NaN NaT NaT
# 96272                                   NEWBORN     2014-02-11  NaN NaT NaT
# 109933                                  NEWBORN     2014-09-05  NaN NaT NaT
# 109947    746.7 HYPOPLASTIC LEFT HEART SYNDROME     2014-11-22  NaN NaT NaT
# 113234                           RETINOBLASTOMA     2014-04-24  NaN NaT NaT
# 113238                            BRONCHIOLITIS     2014-05-08  NaN NaT NaT
# 113242      190.5  MALIGNANT NEOPLASM OF RETINA     2014-05-23  NaN NaT NaT
# 113246                     EXPECT/ HEMOC/ FEVER     2014-06-05  NaN NaT NaT
# 113252      190.5  MALIGNANT NEOPLASM OF RETINA     2014-06-27  NaN NaT NaT
# 113256                     DEHYDRATION AND PAIN     2014-07-31  NaN NaT NaT
# 113260                                    190.5     2014-08-30  NaN NaT NaT
# 113264                 RETINOBLASTOMA TACHYPNEA     2014-09-06  NaN NaT NaT
# 113267                                    190.5     2014-09-27  NaN NaT NaT
# 113271                                      F/N     2014-10-07  NaN NaT NaT
# 115177                                  NEWBORN     2014-09-09  NaN NaT NaT
#
#        Race  age
# 6146      U  NaN
# 6147      U  NaN
# 9140      U  NaN
# 9146      U  NaN
# 12215     U  NaN
# 14042     U  NaN
# 14390     U  NaN
# 15560     U  NaN
# 19987     U  NaN
# 37721     U  NaN
# 47618     U  NaN
# 47899     U  NaN
# 49572     U  NaN
# 51857     U  NaN
# 53621     U  NaN
# 54108     U  NaN
# 54118     U  NaN
# 54119     U  NaN
# 54133     U  NaN
# 54138     U  NaN
# 54141     U  NaN
# 54156     U  NaN
# 54162     U  NaN
# 54163     U  NaN
# 66252     U  NaN
# 80489     U  NaN
# 80552     U  NaN
# 80556     U  NaN
# 81376     U  NaN
# 81377     U  NaN
# 81381     U  NaN
# 96272     U  NaN
# 109933    U  NaN
# 109947    U  NaN
# 113234    U  NaN
# 113238    U  NaN
# 113242    U  NaN
# 113246    U  NaN
# 113252    U  NaN
# 113256    U  NaN
# 113260    U  NaN
# 113264    U  NaN
# 113267    U  NaN
# 113271    U  NaN
# 115177    U  NaN

# %%
len(no_bd.intersection(final))
# Out:
# 41

# %%
newborns = set(adt_age.RUID[adt_age.CHIEF_COMPLAINT == "NEWBORN"])

# %%
newborns.intersection(no_bd)
# Out:
# {53728602,
#  53728684,
#  53729008,
#  53730329,
#  53731021,
#  53731561,
#  53733438,
#  53734654,
#  53735626,
#  53736032}

# %%
len(newborns)
# Out:
# 248
